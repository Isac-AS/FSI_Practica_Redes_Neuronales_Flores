# %% [markdown]
# # Preparación
# Se monta el sistema de archivos de google drive.

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# 2022-01-08 19:29:30.732090: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 19:29:30.732830: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 19:29:30.733241: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 19:29:30.733676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 19:29:30.734023: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 19:29:30.734355: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# '/device:GPU:0'

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
pil_im = Image.open('../input/flowers-recognition/flowers/daisy/100080576_f52e8ee070_n.jpg', 'r')
imshow(np.asarray(pil_im))

# %% [markdown]
# # Carga del dataset

# %%
image_size = (150, 150)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/flowers-recognition/flowers",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/flowers-recognition/flowers",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)

train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)
# Out:
# Found 4317 files belonging to 5 classes.
# Using 3454 files for training.
# Found 4317 files belonging to 5 classes.
# Using 863 files for validation.

# %% [markdown]
# # Modelo

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Rescaling, Flatten, BatchNormalization

# %%
model = keras.Sequential()
model.add(Rescaling(scale=(1./127.5),
                    offset=-1, 
                    input_shape=(150, 150, 3)))

# Capa 1
model.add(Conv2D(96, kernel_size=(11, 11), strides = (4,4), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(3, 3), strides = (2,2)))

# Capa 2
model.add(Conv2D(256, kernel_size=(5, 5), strides = (1,1), activation='relu', padding = "same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(3, 3), strides = (2,2)))

# Capa 3
model.add(Conv2D(384, kernel_size=(3, 3), strides = (1,1), activation='relu', padding = "same"))
model.add(BatchNormalization())

# Capa 4
model.add(Conv2D(384, kernel_size=(3, 3), strides = (1,1), activation='relu', padding = "same"))
model.add(BatchNormalization())

# Capa 5
model.add(Conv2D(256, kernel_size=(3, 3), strides = (1,1), activation='relu', padding = "same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(3, 3), strides = (2,2)))

# Capa 6
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

# Capa 7
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

#Capa 8
model.add(Dense(5, activation='softmax'))

model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adagrad(learning_rate = 0.001),
              metrics=['accuracy'])

# %% [markdown]
# # Visualización del modelo

# %%
from keras.utils.vis_utils import plot_model

plot_model(model, to_file='model_plot.png', show_shapes=True,
           show_layer_names=True)

# %% [markdown]
# # Entrenamiento

# %%
from keras.callbacks import EarlyStopping

epochs = 150

es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=10,
                   restore_best_weights=True)

h = model.fit(
        train_ds,
        epochs=epochs, 
        validation_data=val_ds,
        callbacks = [es]
)
# Out:
# Epoch 1/150
# 108/108 [==============================] - 7s 58ms/step - loss: 1.9054 - accuracy: 0.4317 - val_loss: 1.6946 - val_accuracy: 0.2711
# Epoch 2/150
# 108/108 [==============================] - 6s 54ms/step - loss: 1.3785 - accuracy: 0.5290 - val_loss: 2.2589 - val_accuracy: 0.2711
# Epoch 3/150
# 108/108 [==============================] - 7s 59ms/step - loss: 1.1787 - accuracy: 0.5782 - val_loss: 2.1045 - val_accuracy: 0.3082
# Epoch 4/150
# 108/108 [==============================] - 6s 57ms/step - loss: 1.0476 - accuracy: 0.6123 - val_loss: 1.5614 - val_accuracy: 0.4368
# Epoch 5/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.9600 - accuracy: 0.6384 - val_loss: 1.1705 - val_accuracy: 0.5574
# Epoch 6/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.8482 - accuracy: 0.6882 - val_loss: 0.9225 - val_accuracy: 0.6373
# Epoch 7/150
# 108/108 [==============================] - 7s 60ms/step - loss: 0.7819 - accuracy: 0.7087 - val_loss: 0.8896 - val_accuracy: 0.6686
# Epoch 8/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.7026 - accuracy: 0.7293 - val_loss: 0.9245 - val_accuracy: 0.6466
# Epoch 9/150
# 108/108 [==============================] - 6s 53ms/step - loss: 0.6680 - accuracy: 0.7556 - val_loss: 0.9031 - val_accuracy: 0.6709
# Epoch 10/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.6149 - accuracy: 0.7693 - val_loss: 0.8460 - val_accuracy: 0.6871
# Epoch 11/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.5406 - accuracy: 0.8002 - val_loss: 0.8486 - val_accuracy: 0.6732
# Epoch 12/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.5235 - accuracy: 0.8069 - val_loss: 0.9403 - val_accuracy: 0.6779
# Epoch 13/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.4595 - accuracy: 0.8321 - val_loss: 0.8568 - val_accuracy: 0.6860
# Epoch 14/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.4085 - accuracy: 0.8529 - val_loss: 0.8798 - val_accuracy: 0.6871
# Epoch 15/150
# 108/108 [==============================] - 6s 53ms/step - loss: 0.3543 - accuracy: 0.8691 - val_loss: 0.8866 - val_accuracy: 0.7022
# Epoch 16/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.3175 - accuracy: 0.8825 - val_loss: 0.9019 - val_accuracy: 0.6976
# Epoch 17/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.2888 - accuracy: 0.8995 - val_loss: 0.8792 - val_accuracy: 0.7103
# Epoch 18/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.2635 - accuracy: 0.9079 - val_loss: 0.8701 - val_accuracy: 0.7068
# Epoch 19/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.2193 - accuracy: 0.9288 - val_loss: 0.9243 - val_accuracy: 0.7057
# Epoch 20/150
# 108/108 [==============================] - 7s 59ms/step - loss: 0.1996 - accuracy: 0.9366 - val_loss: 0.9162 - val_accuracy: 0.7242
# Epoch 21/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.1734 - accuracy: 0.9418 - val_loss: 0.9454 - val_accuracy: 0.7277
# Epoch 22/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.1468 - accuracy: 0.9554 - val_loss: 0.9308 - val_accuracy: 0.7115
# Epoch 23/150
# 108/108 [==============================] - 7s 61ms/step - loss: 0.1332 - accuracy: 0.9560 - val_loss: 0.9229 - val_accuracy: 0.7184
# Epoch 24/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.1178 - accuracy: 0.9621 - val_loss: 0.9411 - val_accuracy: 0.7254
# Epoch 25/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.1015 - accuracy: 0.9679 - val_loss: 1.0532 - val_accuracy: 0.6999
# Epoch 26/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0823 - accuracy: 0.9786 - val_loss: 1.0356 - val_accuracy: 0.7057
# Epoch 27/150
# 108/108 [==============================] - 7s 62ms/step - loss: 0.0778 - accuracy: 0.9794 - val_loss: 0.9833 - val_accuracy: 0.7138
# Epoch 28/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0691 - accuracy: 0.9789 - val_loss: 1.0286 - val_accuracy: 0.7161
# Epoch 29/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0701 - accuracy: 0.9823 - val_loss: 1.0304 - val_accuracy: 0.7184
# Epoch 30/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0620 - accuracy: 0.9815 - val_loss: 1.1707 - val_accuracy: 0.7126
# Epoch 31/150
# 108/108 [==============================] - 6s 53ms/step - loss: 0.0523 - accuracy: 0.9861 - val_loss: 1.0035 - val_accuracy: 0.7277
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping

# %% [markdown]
# # Gráfica de evolución de pérdida y exactitud durante el entrenamiento

# %%
import matplotlib.pyplot as plt

plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation','loss', 'val_loss'], loc='upper right')
plt.show()

# %% [markdown]
# # Evaluación de los resultados

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

results = np.concatenate([(y, model.predict(x=x)) for x, y in val_ds], axis=1)

predictions = np.argmax(results[0], axis=1)
labels = np.argmax(results[1], axis=1)

cf_matrix = confusion_matrix(labels, predictions)

sns.heatmap(cf_matrix, annot=True, fmt="d", cmap="Blues")

print(classification_report(labels, predictions, digits = 4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.5985    0.7009    0.6457       117
#            1     0.7863    0.7541    0.7699       244
#            2     0.7086    0.6294    0.6667       170
#            3     0.8267    0.8158    0.8212       152
#            4     0.6859    0.7278    0.7062       180
#
#     accuracy                         0.7277       863
#    macro avg     0.7212    0.7256    0.7219       863
# weighted avg     0.7317    0.7277    0.7285       863

# %%
img = keras.preprocessing.image.load_img(
    '../input/flowers-recognition/flowers/daisy/10172636503_21bededa75_n.jpg', target_size=image_size
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
print(np.argmax(predictions[0]))
# Out:
# 1

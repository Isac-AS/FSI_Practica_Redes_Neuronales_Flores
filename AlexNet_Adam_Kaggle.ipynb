# %% [markdown]
# # Preparación
# Se monta el sistema de archivos de google drive.

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# 2022-01-08 19:02:32.897927: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 19:02:32.898636: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 19:02:32.899110: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 19:02:32.899999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 19:02:32.900500: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 19:02:32.900934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 1
# '/device:GPU:0'
# 5403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
pil_im = Image.open('../input/flowers-recognition/flowers/daisy/100080576_f52e8ee070_n.jpg', 'r')
imshow(np.asarray(pil_im))

# %% [markdown]
# # Carga del dataset

# %%
image_size = (150, 150)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/flowers-recognition/flowers",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/flowers-recognition/flowers",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)

train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)
# Out:
# Found 4317 files belonging to 5 classes.
# Using 3454 files for training.
# Found 4317 files belonging to 5 classes.
# Using 863 files for validation.

# %% [markdown]
# # Modelo

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Rescaling, Flatten, BatchNormalization

# %%
model = keras.Sequential()
model.add(Rescaling(scale=(1./127.5),
                    offset=-1, 
                    input_shape=(150, 150, 3)))

# Capa 1
model.add(Conv2D(96, kernel_size=(11, 11), strides = (4,4), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(3, 3), strides = (2,2)))

# Capa 2
model.add(Conv2D(256, kernel_size=(5, 5), strides = (1,1), activation='relu', padding = "same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(3, 3), strides = (2,2)))

# Capa 3
model.add(Conv2D(384, kernel_size=(3, 3), strides = (1,1), activation='relu', padding = "same"))
model.add(BatchNormalization())

# Capa 4
model.add(Conv2D(384, kernel_size=(3, 3), strides = (1,1), activation='relu', padding = "same"))
model.add(BatchNormalization())

# Capa 5
model.add(Conv2D(256, kernel_size=(3, 3), strides = (1,1), activation='relu', padding = "same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(3, 3), strides = (2,2)))

# Capa 6
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

# Capa 7
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

#Capa 8
model.add(Dense(5, activation='softmax'))

model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %% [markdown]
# # Visualización del modelo

# %%
from keras.utils.vis_utils import plot_model

plot_model(model, to_file='model_plot.png', show_shapes=True,
           show_layer_names=True)

# %% [markdown]
# # Entrenamiento

# %%
from keras.callbacks import EarlyStopping

epochs = 150

es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=10,
                   restore_best_weights=True)

h = model.fit(
        train_ds,
        epochs=epochs, 
        validation_data=val_ds,
        callbacks = [es]
)
# Out:
# Epoch 1/150
# 108/108 [==============================] - 8s 59ms/step - loss: 3.2618 - accuracy: 0.4189 - val_loss: 1.2844 - val_accuracy: 0.4890
# Epoch 2/150
# 108/108 [==============================] - 7s 59ms/step - loss: 1.2441 - accuracy: 0.5211 - val_loss: 1.3431 - val_accuracy: 0.4415
# Epoch 3/150
# 108/108 [==============================] - 6s 55ms/step - loss: 1.1380 - accuracy: 0.5634 - val_loss: 1.1824 - val_accuracy: 0.5701
# Epoch 4/150
# 108/108 [==============================] - 6s 56ms/step - loss: 1.0677 - accuracy: 0.6045 - val_loss: 1.0384 - val_accuracy: 0.5944
# Epoch 5/150
# 108/108 [==============================] - 6s 55ms/step - loss: 1.0371 - accuracy: 0.6115 - val_loss: 1.0738 - val_accuracy: 0.6072
# Epoch 6/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.9631 - accuracy: 0.6500 - val_loss: 1.2660 - val_accuracy: 0.5214
# Epoch 7/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.9633 - accuracy: 0.6485 - val_loss: 1.0095 - val_accuracy: 0.6049
# Epoch 8/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.8994 - accuracy: 0.6740 - val_loss: 0.9792 - val_accuracy: 0.6431
# Epoch 9/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.8872 - accuracy: 0.6899 - val_loss: 1.1109 - val_accuracy: 0.5747
# Epoch 10/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.8467 - accuracy: 0.7030 - val_loss: 1.0701 - val_accuracy: 0.6257
# Epoch 11/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.8261 - accuracy: 0.7140 - val_loss: 1.1562 - val_accuracy: 0.5875
# Epoch 12/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.8033 - accuracy: 0.7148 - val_loss: 1.0356 - val_accuracy: 0.6269
# Epoch 13/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.7762 - accuracy: 0.7273 - val_loss: 0.8655 - val_accuracy: 0.6941
# Epoch 14/150
# 108/108 [==============================] - 7s 57ms/step - loss: 0.7700 - accuracy: 0.7221 - val_loss: 0.9615 - val_accuracy: 0.6686
# Epoch 15/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.7051 - accuracy: 0.7548 - val_loss: 1.1280 - val_accuracy: 0.5805
# Epoch 16/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.6762 - accuracy: 0.7684 - val_loss: 1.0291 - val_accuracy: 0.6640
# Epoch 17/150
# 108/108 [==============================] - 6s 53ms/step - loss: 0.6691 - accuracy: 0.7739 - val_loss: 0.7874 - val_accuracy: 0.7115
# Epoch 18/150
# 108/108 [==============================] - 7s 63ms/step - loss: 0.6624 - accuracy: 0.7756 - val_loss: 0.9852 - val_accuracy: 0.6883
# Epoch 19/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.5919 - accuracy: 0.7918 - val_loss: 0.9490 - val_accuracy: 0.6802
# Epoch 20/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.5818 - accuracy: 0.8115 - val_loss: 0.8149 - val_accuracy: 0.7161
# Epoch 21/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.5209 - accuracy: 0.8225 - val_loss: 0.9858 - val_accuracy: 0.7138
# Epoch 22/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.5032 - accuracy: 0.8260 - val_loss: 0.9503 - val_accuracy: 0.7068
# Epoch 23/150
# 108/108 [==============================] - 6s 53ms/step - loss: 0.4597 - accuracy: 0.8382 - val_loss: 1.2120 - val_accuracy: 0.7068
# Epoch 24/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.4509 - accuracy: 0.8416 - val_loss: 1.9324 - val_accuracy: 0.5238
# Epoch 25/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.4510 - accuracy: 0.8477 - val_loss: 0.9878 - val_accuracy: 0.7300
# Epoch 26/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.4062 - accuracy: 0.8622 - val_loss: 1.0265 - val_accuracy: 0.7242
# Epoch 27/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.3698 - accuracy: 0.8703 - val_loss: 1.0001 - val_accuracy: 0.7242
# Epoch 28/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.3486 - accuracy: 0.8827 - val_loss: 1.0877 - val_accuracy: 0.7300
# Epoch 29/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.3242 - accuracy: 0.8943 - val_loss: 1.1372 - val_accuracy: 0.7196
# Epoch 30/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.3926 - accuracy: 0.8694 - val_loss: 0.9080 - val_accuracy: 0.6860
# Epoch 31/150
# 108/108 [==============================] - 7s 62ms/step - loss: 0.3851 - accuracy: 0.8686 - val_loss: 1.2634 - val_accuracy: 0.6952
# Epoch 32/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.3326 - accuracy: 0.8958 - val_loss: 0.9698 - val_accuracy: 0.7346
# Epoch 33/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.2846 - accuracy: 0.9085 - val_loss: 0.9819 - val_accuracy: 0.7509
# Epoch 34/150
# 108/108 [==============================] - 6s 58ms/step - loss: 0.2714 - accuracy: 0.9131 - val_loss: 1.1282 - val_accuracy: 0.7265
# Epoch 35/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.3110 - accuracy: 0.9030 - val_loss: 1.1186 - val_accuracy: 0.7300
# Epoch 36/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.5069 - accuracy: 0.8468 - val_loss: 1.0567 - val_accuracy: 0.7126
# Epoch 37/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.2989 - accuracy: 0.8969 - val_loss: 1.4252 - val_accuracy: 0.6999
# Epoch 38/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.2421 - accuracy: 0.9268 - val_loss: 1.2195 - val_accuracy: 0.7254
# Epoch 39/150
# 108/108 [==============================] - 6s 53ms/step - loss: 0.2277 - accuracy: 0.9265 - val_loss: 1.2737 - val_accuracy: 0.6952
# Epoch 40/150
# 108/108 [==============================] - 6s 53ms/step - loss: 0.2407 - accuracy: 0.9247 - val_loss: 1.1242 - val_accuracy: 0.7115
# Epoch 41/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.1685 - accuracy: 0.9508 - val_loss: 1.2647 - val_accuracy: 0.7358
# Epoch 42/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.2089 - accuracy: 0.9346 - val_loss: 1.5114 - val_accuracy: 0.7173
# Epoch 43/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.1610 - accuracy: 0.9519 - val_loss: 1.1229 - val_accuracy: 0.7393
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping

# %% [markdown]
# # Gráfica de evolución de pérdida y exactitud durante el entrenamiento

# %%
import matplotlib.pyplot as plt

plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation','loss', 'val_loss'], loc='upper right')
plt.show()

# %% [markdown]
# # Evaluación de los resultados

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

results = np.concatenate([(y, model.predict(x=x)) for x, y in val_ds], axis=1)

predictions = np.argmax(results[0], axis=1)
labels = np.argmax(results[1], axis=1)

cf_matrix = confusion_matrix(labels, predictions)

sns.heatmap(cf_matrix, annot=True, fmt="d", cmap="Blues")

print(classification_report(labels, predictions, digits = 4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.7080    0.8083    0.7549       120
#            1     0.8675    0.7719    0.8169       263
#            2     0.4967    0.7576    0.6000        99
#            3     0.8667    0.8025    0.8333       162
#            4     0.7487    0.6530    0.6976       219
#
#     accuracy                         0.7509       863
#    macro avg     0.7375    0.7586    0.7405       863
# weighted avg     0.7725    0.7509    0.7562       863

# %%
img = keras.preprocessing.image.load_img(
    '../input/flowers-recognition/flowers/daisy/10172636503_21bededa75_n.jpg', target_size=image_size
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
print(np.argmax(predictions[0]))
# Out:
# 1
